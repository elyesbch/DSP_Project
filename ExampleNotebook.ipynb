# %% [markdown]
# # Example Notebook

# %% [markdown]
# ## Load all files and visualize

# %%
from DataProcessor import DataProcessor
from axiamo_lib.Visualizer import Visualizer

dp = DataProcessor("rawdata/X22/Excersice_2/rennen_hakim/Mes_1")

all_data_files = dp.find_all_data_files()
print(all_data_files)
for fileName in all_data_files:
    print(f"Visualizing file: {fileName}")  
    dp.loadRawData(fileName)
    for dev in dp.getDevices():
        vis = Visualizer()
        print("Processing device: {dev}")
        dp.loadRawDataDevice(dev)
        vis.setDataSet(dp.ds)
        vis.visualizeRawDataSubPlot(dp,fileName)
# Out:
# ['rawdata/X22/Excersice_2/rennen_hakim/Mes_1\\19700101_000004.pickle', 'rawdata/X22/Excersice_2/rennen_hakim/Mes_1\\20260506_103629.pickle', 'rawdata/X22/Excersice_2/rennen_hakim/Mes_1\\20260507_123618.pickle', 'rawdata/X22/Excersice_2/rennen_hakim/Mes_1\\20260507_124135.pickle', 'rawdata/X22/Excersice_2/rennen_hakim/Mes_1\\20260507_124234.pickle']
# Visualizing file: rawdata/X22/Excersice_2/rennen_hakim/Mes_1\19700101_000004.pickle
# Processing device: {dev}
# Visualizing file: rawdata/X22/Excersice_2/rennen_hakim/Mes_1\20260506_103629.pickle
# Processing device: {dev}
# Visualizing file: rawdata/X22/Excersice_2/rennen_hakim/Mes_1\20260507_123618.pickle
# Processing device: {dev}
# Visualizing file: rawdata/X22/Excersice_2/rennen_hakim/Mes_1\20260507_124135.pickle
# Processing device: {dev}
# Visualizing file: rawdata/X22/Excersice_2/rennen_hakim/Mes_1\20260507_124234.pickle
# Processing device: {dev}

# %% [markdown]
# ## Load specific file and plot

# %%
import matplotlib.pyplot as plt
from DataProcessor import DataProcessor

# %matplotlib inline

dp = DataProcessor("rawdata/")
fileName = 'rawdata/X22/rennen1.pickle'
dp.loadRawData(fileName)
for dev in dp.getDevices():
    dp.loadRawDataDevice(dev)

print(dp.ds.dfAcc)           # Pandas DataFrame with all the data from the accelerometer
#print(dp.ds.dfAcc['t'])     # Time vector
#print(dp.ds.dfAcc['x'])     # x axis accelerometer
#print(dp.ds.dfAcc['y'])     # y axis accelerometer
#print(dp.ds.dfAcc['z'])     # z axis accelerometer

plt.figure()
plt.plot(dp.dfAcc['t'], dp.dfAcc['x'], label='X Axis Accelerometer', color='green')
plt.title('X Axis Accelerometer')
plt.xlabel('Time [s]')
plt.ylabel('Acceleration [g]')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#             t         x         y         z
# 0       0.000 -0.515816 -0.100528 -0.871568
# 1       0.005 -0.508496 -0.127856 -0.841800
# 2       0.010 -0.472384 -0.149816 -0.867176
# 3       0.015 -0.441640 -0.183000 -0.839848
# 4       0.020 -0.471408 -0.126880 -0.872544
# ...       ...       ...       ...       ...
# 10491  52.455 -0.014640  0.031720 -0.987224
# 10492  52.460 -0.015128  0.031232 -0.986736
# 10493  52.465 -0.014640  0.032208 -0.987224
# 10494  52.470 -0.015128  0.030744 -0.989664
# 10495  52.475 -0.015128  0.030744 -0.988688
#
# [10496 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from DataProcessor import DataProcessor

# %matplotlib inline

dp = DataProcessor("rawdata/")
files = ['rawdata/X22/Excersice_2/normal_gehen/normal_gehen_hakim5.pickle', 
         'rawdata/X22/Excersice_2/schnell_gehen/surija5.pickle', 
         'rawdata/X22/Excersice_2/rennen/Hakim_rennnen_5.pickle'];

for i in range(3): 
    fileName = files[i]
    dp.loadRawData(fileName)
    for dev in dp.getDevices():
        dp.loadRawDataDevice(dev)

    print(dp.ds.dfAcc)           # Pandas DataFrame with all the data from the accelerometer
    #print(dp.ds.dfAcc['t'])     # Time vector
    #print(dp.ds.dfAcc['x'])     # x axis accelerometer
    #print(dp.ds.dfAcc['y'])     # y axis accelerometer
    #print(dp.ds.dfAcc['z'])     # z axis accelerometer

    plt.figure()
    plt.plot(dp.dfAcc['t'], dp.dfAcc['x'], label='X Axis Accelerometer', color='green')
    plt.title('X Axis Accelerometer')
    plt.xlabel('Time [s]')
    plt.ylabel('Acceleration [g]')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
#             t         x         y         z
# 0       0.000 -0.517280 -4.497408  3.188592
# 1       0.005  2.553704 -1.902712  0.607072
# 2       0.010 -1.024800 -4.243160  4.222664
# 3       0.015 -1.380552 -5.490488  4.924896
# 4       0.020 -0.794464 -1.834880  2.164280
# ...       ...       ...       ...       ...
# 13051  65.255  0.214720  0.680272 -0.688568
# 13052  65.260  0.209352  0.673440 -0.682224
# 13053  65.265  0.208864  0.669536 -0.683200
# 13054  65.270  0.214232  0.672952 -0.681736
# 13055  65.275  0.218136  0.679296 -0.675392
#
# [13056 rows x 4 columns]
#             t         x         y         z
# 0       0.000 -0.515816 -0.100528 -0.871568
# 1       0.005 -0.508496 -0.127856 -0.841800
# 2       0.010 -0.472384 -0.149816 -0.867176
# 3       0.015 -0.441640 -0.183000 -0.839848
# 4       0.020 -0.471408 -0.126880 -0.872544
# ...       ...       ...       ...       ...
# 10491  52.455 -0.014640  0.031720 -0.987224
# 10492  52.460 -0.015128  0.031232 -0.986736
# ...
